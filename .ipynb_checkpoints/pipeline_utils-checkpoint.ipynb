# %%
#import etl pipeline
import pandas as pd

from etl_pipeline import extract, transform, load
from airflow import DAG
from airflow.providers.standard.operators.python import PythonOperator
from airflow.providers.smtp.operators.smtp import EmailOperator
from datetime  import datetime




def printme():
    print("This goes in the logs!")
    python_task = PythonOperator(
        task_id='simple_print',
        python_callable=printme
        )


email_task = EmailOperator(
    task_id='email_sales_report',
    to='leonelsalmos@gmail.com',
    subject='Automated Sales Report',
    html_content='Attached is the latest sales report',
    files='latest_sales.xlsx'
    )


default_arguments = {
    'owner': 'leonel',
    'email': 'leonelsalmos@gmail.com',
    'start_date': datetime(2026, 5, 2)
}
etl_dag = DAG('etl_workflow', default_args=default_arguments )


#teste as funcoes do ETL
#dataframe = extract("datasets/one_piece.json")
#transformed_stock_data = pd.DataFrame(dataframe)
#print(transformed_stock_data)
#print(dataframe)
#dataframe = transform()
#print(dataframe)
#dataframe = load()
dataframe = load() 
print(dataframe)
# Out:
# DEBUG: Initializing Providers Manager[config]
# DEBUG: Initializing Providers Manager[list]
# DEBUG: Loading EntryPoint(name='provider_info', value='airflow.providers.standard.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-standard
# DEBUG: Loading EntryPoint(name='provider_info', value='airflow.providers.common.compat.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-common-compat
# DEBUG: Loading EntryPoint(name='provider_info', value='airflow.providers.smtp.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-smtp
# DEBUG: Loading EntryPoint(name='provider_info', value='airflow.providers.common.io.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-common-io
# DEBUG: Loading EntryPoint(name='provider_info', value='airflow.providers.common.sql.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-common-sql
# DEBUG: Initialization of Providers Manager[list] took 0.06 seconds
# DEBUG: Initialization of Providers Manager[config] took 0.06 seconds
# INFO: Reading the config from /home/leonel-cassule/airflow/airflow.cfg
# INFO: Configured default timezone UTC
# INFO: Loaded airflow_local_settings from /home/leonel-cassule/airflow/config/airflow_local_settings.py .
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 46
#      42 #print(dataframe)
#      43 #dataframe = transform()
#      44 #print(dataframe)
#      45 #dataframe = load()
# ---> 46 dataframe = load()
#      47 print(dataframe)
#
# File ~/Documentos/GitHub/One_Piece_Anime/etl_pipeline.py:37, in load()
#      36 def load():
# ---> 37    stock_data.to_csv("datasets/datos")
#      38    return stock_data.head()
#
# NameError: name 'stock_data' is not defined
