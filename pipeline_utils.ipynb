# %%
#import etl pipeline
import pandas as pd
from test_etl_pipeline import extract, transform, load

#from airflow.providers.standard.operators.python import PythonOperator
#from airflow.providers.smtp.operators.smtp import EmailOperator
#from datetime  import datetime

"""


def printme():
    print("This goes in the logs!")
    python_task = PythonOperator(
        task_id='simple_print',
        python_callable=printme
        )


email_task = EmailOperator(
    task_id='email_sales_report',
    to='leonelsalmos@gmail.com',
    subject='Automated Sales Report',
    html_content='Attached is the latest sales report',
    files='latest_sales.xlsx'
    )


default_arguments = {
    'owner': 'leonel',
    'email': 'leonelsalmos@gmail.com',
    'start_date': datetime(2026, 5, 2)
}
etl_dag = DAG('etl_workflow', default_args=default_arguments )


#transformed_stock_data = pd.DataFrame(dataframe)
#print(transformed_stock_data)
#print(dataframe)
#dataframe = transform()
#print(dataframe)
#dataframe = load()
dataframe = load() 
print(dataframe)
"""
# Out:
# INFO: A extração de Dados do Arquivo Json foi feito com Sucesso!
#                0       1       2       3       4       5       6       7    \
# Unnamed: 0       0       1       2       3       4       5       6       7
# rank        24,129  29,290  32,043  28,818  37,113  36,209  37,648  38,371
# trend           18      11       7       8       4       4       4       6
# season           1       1       1       1       1       1       1       1
# episode          1       2       3       4       5       6       7       8
#
#                8       9    ...     948     949     950     951     952  \
# Unnamed: 0       8       9  ...     948     949     950     951     952
# rank        42,249  41,829  ...  50,714  49,737  59,574  54,156  45,193
# trend            5       4  ...      16      15      15      16      28
# season           1       1  ...       1       1       1       1       1
# episode          9      10  ...     949     950     951     952     953
#
#                953     954     955    956     957
# Unnamed: 0     953     954     955    956     957
# rank        41,448  35,342  33,715  2,940  14,751
# trend           26      44      75    964       -
# season           1       1       1      1       1
# episode        954     955     956    957     958
#
# [5 rows x 958 columns]
